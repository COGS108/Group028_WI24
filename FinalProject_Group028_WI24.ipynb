# %% [markdown]
# # COGS 108 - Deciphering Success in Cinema: Analyzing the Impact of Runtime, Budget, Genre, MPA Rating, and Release Timing on IMDB Scores and Revenue
#
# # Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public. (Note that student names will be included (but PIDs will be scraped from any groups who include their PIDs).
#
# * [ X  ] YES - make available
# * [  ] NO - keep private

# %% [markdown]
# # Names
#
# - James DeLisio
# - Karisma Kumar
# - Chi Kiet Chou (Jack)
# - Anthony Gonzalez
# - Chengyuan Mao

# %% [markdown]
# # Abstract
#
# To begin we wanted to look at a field somewhat interesting to all of us, the film industry. Initially we wanted to see if film runtimes correlated with user ratings, for example whether longer films had better ratings than shorter ones. This lead our intial dive into the different possible variables that could influence the rating of a film, leaving us with a list of 5 potential variables for a film's rating: film runtime, adjusted film budget, film genre, film's MPA (Motion Picture Association) Rating, and the film's release month. With this we also wanted to extend our findings not just for user ratings but also the film's generated revenue as another representation of a film's success.
#
# To answer our research question we began by gathering a dataset of movies from 1980-2020 which contains all of our needed variables plus various more. With this we cleaned the dataset to only have the factors we are looking for and removed all of the films which did not have the factors we were studying. Next in an attempt to normalize the financial aspects of the films, we adjusted all of the revenue and budget values for inflation. With this our dataset was cleaned, so we began to run an analysis of the factors relations to the score and revenue. In conclusion we found that there were differences between factors that lead to greater film revenue compared to the user's scores for films. This shows there may be different factors to emphasize depending on what form of success the film is seeking being monetary success or audience perception of the film.

# %% [markdown]
# # Research Question

# %% [markdown]
# Our research question sets out to examine what characteristics of movies influence their user rating score on IMDB. In particular, we will look at the runtime, budget, genre, MPA (Motion Picture Association) Rating, and release month to see if any of these metrics correlate with movie’s average user rating score on IMDB. In addition, we want to treat revenue as a secondary outcome variable, and see how each factor listed earlier correlates with a film's revenue. Furthermore, we are curious about the relationship between revenue made by the movies and its user ratings.

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# The film industry has grown to one of the most competitive and expensive industries. Being one of the most influential forms of entertainment, studios compete against each other by making intentional choices and investing money in certain films, hoping for great returns from critics and audiences. Many large tech companies like Apple and Amazon pivoting toward the film industry to capitalize on successful movies to drive their comercial revenue, highlighting the power that films have as a source of profit for studios and companies. Thus, we are interested in seeing what kinds of movies are most favorable with audiences.This brings up the significance of movie ratings: IMDB, one of the largest and most popular movie databases, allows users to rate movies on a scale from 1-10. Due to its large number of users, IMDB's user ratings act as a relatively representative and direct metric for an audience's opinions on a film. In the paper “A Predictor for Movie Success”<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1), Ericson and Grodman proposed using machine learning to determine the relationships between sets of metrics about a film, and the film’s critics scores, audience scores, US gross revenue, open weekend gross revenue, and film’s IMDB rating. These sets of metrics contain the factors that we are interested in studying, among others. One of these models highlighted the audience score as the best predictor for a film’s success among all factors. This confirms our belief that there is a correlation between the features that we selected, with audience ratings.
#
# Although the film industry is highly competitive, it has been seen several times that indie movies with low budgets from unknown studios can defy expectations with high revenue and ratings. In another study by Max Wasserman et al<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2), they pointed out the historical changes in correlation between movie budget and user ratings. Their results show a strong positive correlation between a film's budget and user ratings overall. However, the rise of independent distribution companies like A24 and Neon in recent years have made the earning potential for low-budget films higher than they have been historically. This suggests that the relationship between a film's budget and its user rating on IMDB may be more complicated than we initially thought. We hope to further investigate this relationship in our project.
#
# With bigger budgets, movie studios and directors would concievably have more flexibility in choosing their film’s genre choices, runtime, release date, and even content, targeting specific MPA ratings to appeal to audiences with a certain level of maturity. All of these factors have their own advantages and tradeoffs for user ratings. In a paper by Pedro Garcia-del-Barrio and Hugo Zarco<a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3), they analyzed the influence of a film’s contents with its box office revenue. They included factors such as genre, mature content, and release season in their analysis. Their results showed a significant influence for all of those factors with box office revenue across 4 models. Furthermore, they also showed that certain genres of film have more significance than others, supporting our initial idea in our research question that certain types of films may systematically perform better than others. Although this paper didn’t cover user ratings, “A Predictor for Movie Success”<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) points out the positive correlation between a movie’s revenue and its user ratings. This suggests that the relationships we see between a film's characteristics and its revenue may also hold true for its user ratings, and vice versa. Hence, we hope to see the influence of genre, release date, and mature content (associated with a higher MPA Rating) translated into user ratings in our analysis.
#
# While a film’s rating is a direct metric to measure the audience’s satisfaction, a profitable movie does not always make it highly rated, and vice versa. However, from the studio’s perspective, a lucrative film is a success. As such, we are also interested in seeing how the prior factors correlate to a film’s overall revenue.
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Ericson, J., & Goodman, J. (2013). A predictor for movie success. CS229, Stanford University. https://cs229.stanford.edu/proj2013/EricsonGrodman-APredictorForMovieSuccess.pdf
#
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Gama, D. (2023). Wasserman, M., Mukherjee, S., Scott, K., Zeng, X. H. T., Radicchi, F., & Amaral, L. A. (2015). Correlations between user voting data, budget, and box office for films in the internet movie database. Journal of the Association for Information Science and Technology, 66(4), 858-868. https://cgi.luddy.indiana.edu/~filiradi/Mypapers/asi23213.pdf
#
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) Garcia-del-Barrio, P., & Zarco, H. (2017). Do movie contents influence box-office revenues?. Applied Economics, 49(17), 1679-1688. https://merit.url.edu/en/publications/do-movie-contents-influence-box-office-revenues

# %% [markdown]
# # Hypothesis

# %% [markdown]
# We predict that of all of our listed factors, the budget and MPA rating of a film will be most strongly correlated with the IMDB average audience rating, with higher budgets and “R” ratings correlating with higher audience ratings. We predict that longer runtimes, being a drama, and being released during the summer will also correlate with a higher average rating on IMDB, since we imagine longer dramas released during summer blockbuster season are more likely to perform well with critics. Similarly, we expect the correlation of each factor will remain the same when put against revenue. In addition, we predict that revenue has a positive correlation with the average user ratings.

# %% [markdown]
# # Data

# %% [markdown]
# ## Data overview
#
# - Dataset #1: "Movie Industry" Dataset
#   - Dataset Name: "Movie Industry"
#   - Link to the dataset: https://www.kaggle.com/datasets/danielgrijalvas/movies
#   - Number of observations: 6820
#   - Number of variables: 15
# - Dataset #2: "Consumer Price Index for All Urban Consumers"
#   - Dataset name: "Consumer Price Index for All Urban Consumers: All Items in U.S. City Average"
#   - Link to dataset: https://fred.stlouisfed.org/series/CPIAUCSL (sourced from the Federal Reserve Bank of St. Louis website)
#   - Number of observations: 925
#   - Number of variables: 2
#
# The primary dataset we will be using is titled "Movie Industry" by Daniel Grijalva (https://www.kaggle.com/datasets/danielgrijalvas/movies), sourced from Kaggle. This dataset contains several metrics about a selection of films from every year from 1980-2020, including all of the factors we want to test in our hypothesis. The key variables we will be selecting are:
# - "name" : gives the movie name as a string.
# - "year : gives the film's release year as an int.
# - "released" : gives the film's release date in YYYY-MM-DD format as a string.
# - "budget" : gives the film's estimated budget in USD (not adjusted for inflation)
# - "gross" : gives the film's estimated gross revenue in USD (not adjusted for inflation)
# - "runtime" : gives the film's runtime in minutes as an int
# - "genre" : gives the film's main genre as a string
# - "score" : gives the film's average user rating on IMDB
#
# These variables are all direct measures of the factors we want to examine in our hypothesis, so most of the wrangling necessary will simply be removing unecessary columns, dealing with NA values, and renaming columns for better usability. Also, we will need to convert the budget and revenue values to account for inflation, so that we can accurately compare the fiscal information for the films across time.
#
# The second dataset contains the Consumer Price Index (CPI) averaged for all urban consumer goods for every month from 1947 until January, 2024. The CPI is a useful price index that allows the adjustment of dollar amounts in any year into any other year, accounting for inflation. We will be using this CPI information to correct our film budgets and revenues for inflation, allowing for a fair comparison of their budgets and earnings. The data will not need to be cleaned much, but we will need to wrangle it into a yearly format instead of a monthly one. The key variables of interest are:
# - DATE: Lists the date that the CPI was calculated, in YYYY-MM-DD format as as string.
# - CPI: Lists the CPI, as an int.
#
# We will combine these datasets into one by creating a 'year' column that they have in common and merging them on that shared column.

# %% [markdown]
# ## Dataset #1: "Movie Industry" Dataset
# **SETUP**
#
# First, we install pandas and seaborn, which we will be using for our analysis.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import patsy
import statsmodels.api as sm
from scipy.stats import linregress

pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# Next, we load our dataset and look at the first few rows.

# %%
df = pd.read_csv('./assets/movies.csv')
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)   8.40  927000.00  Stanley Kubrick
# 1   July 2, 1980 (United States)   5.80   65000.00   Randal Kleiser
# 2  June 20, 1980 (United States)   8.70 1200000.00   Irvin Kershner
# 3   July 2, 1980 (United States)   7.70  221000.00     Jim Abrahams
# 4  July 25, 1980 (United States)   7.30  108000.00     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %% [markdown]
# Thankfully, it does not appear that our data needs much cleaning, as it is already relatively standardized. The main things we will need to do are to remove missing values, extract the release month from the 'released' column, and adjust the budget and revenue information for inflation.
#
# First, we will drop all rows containing NA values, or rows where the "budget", "runtime", or "gross" are equal to 0. In the dataset notes on Kaggle, it was specified that these numerical values have a 0 where there was no data available, so we are treating 0 as an NA for these columns. We are dropping the entire row if any column is NA, since we would not be able to compare it to the other films in the dataset.

# %%
df = df.dropna()
df = df[(df['budget'] != 0) & (df['gross'] != 0) & (df['runtime'] != 0)]

# %% [markdown]
# Next, we will adjust our dataframe so it only includes the columns that are relevant to our research question. We chose to keep "year" even though it is not one of the factors we're interested in, since we will need to know what year a movie came out in to adjust the revenue and budget for inflation.
#
# Looking at our dataset now that we have removed the missing values and renamed some columns for clarity, we can see that there are 5421 observations for us to work with in our analysis.

# %%
#Grabbing relevant rows
df = df[['name', 'rating', 'genre', 'year', 'released', 'score', 'budget', 'gross', 'runtime']]
cleaned_df = df.rename(columns={'gross': 'revenue'})
cleaned_df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score       budget  \
# ...

# %% [markdown]
# Next, we will be extracting the release month from the 'released' column.
#
# To do so, we will be defining a function 'extract_month()' that checks the value of the 'released' column, and replaces it with only the month that is listed.

# %%
def extract_month(string):
    
    #convert the strings into usable format
    string = string.lower()
    string = string.strip()

    #Check to see which month the release date information contains, then preserving only that month
    if 'january' in string:
        string = 'January'
    elif 'february' in string:
        string = 'February'
    elif 'march' in string:
        string = 'March'
    elif 'april' in string:
        string = 'April'
    elif 'may' in string:
        string = 'May'
    elif 'june' in string:
        string = 'June'
    elif 'july' in string:
        string = 'July'
    elif 'august' in string:
        string = 'August'
    elif 'september' in string:
        string = 'September'
    elif 'october' in string:
        string = 'October'
    elif 'november' in string:
        string = 'November'
    elif 'december' in string:
        string = 'December'
    
    # If there is no release month, drop it from the dataset.

    else:
        string = np.NAN

    return string

# %% [markdown]
# Next, we apply extract_month() to our 'released' column to ensure that it properly extracted the release month.

# %%
cleaned_df['released'] = cleaned_df['released'].apply(extract_month)

# %% [markdown]
# Finally, we rename the 'released' column to reflect the fact that it now only stores the month that the film was released in.

# %%
df = cleaned_df.rename(columns={'released' : 'month'})

# %% [markdown]
# ## Dataset #2: "Consumer Price Index for All Urban Consumers"
# The rest of our data cleaning involves adjusting the budget and revenue information for inflation. To do this, we will need to bring in a second dataset containing the Consumer Price Index in the US per year. This information is necessary for adjusting dollar amounts for inflation over time.

# %% [markdown]
# First, we import the CPI dataset and take a look at it.

# %%
cpi = pd.read_csv('./assets/CPIAUCSL.csv')
cpi
# Out:
#            DATE  CPIAUCSL
# 0    1947-01-01     21.48
# 1    1947-02-01     21.62
# 2    1947-03-01     22.00
# 3    1947-04-01     22.00
# 4    1947-05-01     21.95
# ..          ...       ...
# 920  2023-09-01    307.29
# 921  2023-10-01    307.53
# 922  2023-11-01    308.02
# 923  2023-12-01    308.74
# 924  2024-01-01    309.69
#
# [925 rows x 2 columns]

# %% [markdown]
# First, we will convert the 'DATE' column to datetime objects for ease of use. Then, since our movies dataframe only contains films from 1980 to 2020, we can truncate our cpi dataframe to only contain the information relevant to those years.

# %%
cpi['DATE'] = pd.to_datetime(cpi['DATE'])
# Filtering cpi to only include the years 1980-2020
cpi = cpi[(cpi['DATE'].dt.year <= 2020) & (cpi['DATE'].dt.year >= 1980)]

# %% [markdown]
# This dataframe measures the CPI monthly. For our purposes, we will be averaging the CPI's of a given year into a single CPI value representing that year. This will give us an identical 'year' column between dataframes to merge them later on. We rename the 'DATE' column to 'year' to merge them, and 'CPIAUSCL' to 'CPI' for ease of use.

# %%
# Group the CPI's by year, then take the mean of each year's CPI values
cpi = cpi.groupby(cpi['DATE'].dt.year).mean()
cpi.reset_index(drop=True)

# Truncate the information in the 'DATE' column to only show the year next to its calculated average CPI.
cpi['DATE'] = cpi['DATE'].dt.year
cpi = cpi.rename(columns={'DATE' : 'year', 'CPIAUCSL' : 'CPI'})
cpi.reset_index(drop=True)
# Out:
#     year    CPI
# 0   1980  82.38
# 1   1981  90.93
# 2   1982  96.53
# 3   1983  99.58
# 4   1984 103.93
# 5   1985 107.60
# 6   1986 109.69
# 7   1987 113.62
# 8   1988 118.27
# 9   1989 123.94
# 10  1990 130.66
# 11  1991 136.17
# 12  1992 140.31
# 13  1993 144.47
# 14  1994 148.22
# 15  1995 152.38
# 16  1996 156.86
# 17  1997 160.53
# 18  1998 163.01
# 19  1999 166.58
# 20  2000 172.19
# 21  2001 177.04
# 22  2002 179.87
# 23  2003 184.00
# 24  2004 188.91
# 25  2005 195.27
# 26  2006 201.56
# 27  2007 207.34
# 28  2008 215.25
# 29  2009 214.56
# 30  2010 218.08
# 31  2011 224.92
# 32  2012 229.59
# 33  2013 232.95
# 34  2014 236.72
# 35  2015 237.00
# 36  2016 240.01
# 37  2017 245.12
# 38  2018 251.10
# 39  2019 255.65
# 40  2020 258.85

# %% [markdown]
# Now that we have a table of CPI values for each year in our movies dataframe, we just need to calculate one more piece of information before we can merge our dataframes and begin to adjust our figures for inflation.
#
# To do so, you first set set a "base year" (in our case, 2020). Then, you divide the CPI in each year by the base year's CPI. Finally, you divide the actual dollar amount from the original year by that number to give you a figure adjusted for inflation to your base year.
#
# We will now add a new column to the CPI dataframe which stores the result of dividing each price index by the base year's CPI. We will call this value the 'inflation_adjustment'

# %%
# Dividing each CPI value by the CPI value for 2020 and storing in a new column
cpi['inflation_adjustment'] = cpi['CPI'] / cpi.iloc[40, 1]
cpi
# Out:
#       year    CPI  inflation_adjustment
# DATE
# 1980  1980  82.38                  0.32
# 1981  1981  90.93                  0.35
# 1982  1982  96.53                  0.37
# 1983  1983  99.58                  0.38
# 1984  1984 103.93                  0.40
# 1985  1985 107.60                  0.42
# 1986  1986 109.69                  0.42
# 1987  1987 113.62                  0.44
# 1988  1988 118.27                  0.46
# 1989  1989 123.94                  0.48
# 1990  1990 130.66                  0.50
# 1991  1991 136.17                  0.53
# 1992  1992 140.31                  0.54
# 1993  1993 144.47                  0.56
# 1994  1994 148.22                  0.57
# 1995  1995 152.38                  0.59
# 1996  1996 156.86                  0.61
# 1997  1997 160.53                  0.62
# 1998  1998 163.01                  0.63
# 1999  1999 166.58                  0.64
# 2000  2000 172.19                  0.67
# 2001  2001 177.04                  0.68
# ...

# %% [markdown]
# Now that we have all the information we will need in the cpi dataframe, we can merge our two dataframes on their shared 'year' column and adjust our budgets and revenues for inflation.

# %%
# Merging our two dataframes using their shared 'year' column.

combined_df = df.merge(cpi, on='year')
combined_df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 5416                               Bad Boys for Life          R     Action
# 5417                              Sonic the Hedgehog         PG     Action
# 5418                                        Dolittle         PG  Adventure
# 5419                            The Call of the Wild         PG  Adventure
# 5420                               The Eight Hundred  Not Rated     Action
#
# ...

# %% [markdown]
# To adjust our budgets and revenues for inflation, we will divide each value by its inflation_adjustment and store the results in new columns, called 'adjusted_budget' and 'adjusted_revenue'. We will then print the dataset to see if our adjustments were successful. Finally, we keep only the columns needed for the analysis.

# %%
combined_df['adjusted_budget'] = combined_df['budget'] / combined_df['inflation_adjustment']
combined_df['adjusted_revenue'] = combined_df['revenue'] / combined_df['inflation_adjustment']
combined_df.drop(columns=['budget', 'revenue', 'CPI', 'inflation_adjustment'], inplace=True)
combined_df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 5416                               Bad Boys for Life          R     Action
# 5417                              Sonic the Hedgehog         PG     Action
# 5418                                        Dolittle         PG  Adventure
# 5419                            The Call of the Wild         PG  Adventure
# 5420                               The Eight Hundred  Not Rated     Action
#
# ...

# %% [markdown]
# We now have a combined dataset showing each film, along with its characteristic information of interest to our research question, with its budget and revenue corrected for inflation to allows to perform valid comparisons. With all this done, we are ready to begin exploring our data and seeing what correlations exist. Finally, we will look at some summaries and distributions of our key variables (rating, genre, year, month, score, runtime, adjusted_budget, and adjusted_revenue) to make sure there are no more glaring issues.

# %%
# check distribution of ratings in the datset
combined_df['rating'].value_counts()
# Out:
# rating
# R            2597
# PG-13        1729
# PG            907
# G             111
# Not Rated      44
# Unrated        17
# NC-17          12
# TV-MA           2
# Approved        1
# X               1
# Name: count, dtype: int64

# %% [markdown]
# It looks like we have movies for both "Not Rated" as well as "Unrated", which are used interchangably, so we'll merge those categories. TV-MA and "Approved" are also used for TV specials and not movies, so we will drop those entries.

# %%
# Find TV Special observations to drop

to_drop = combined_df[(combined_df['rating'] == "TV-MA") | (combined_df['rating'] == "Approved")]

# %%
# Drop TV specials using the above indeces

combined_df = combined_df.drop([61, 4810, 5399])
combined_df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 5416                               Bad Boys for Life          R     Action
# 5417                              Sonic the Hedgehog         PG     Action
# 5418                                        Dolittle         PG  Adventure
# 5419                            The Call of the Wild         PG  Adventure
# 5420                               The Eight Hundred  Not Rated     Action
#
# ...

# %% [markdown]
# Next, we will convert all instances of "Unrated" to "Not Rated" since they are interchangable to the MPA.

# %%
# convert all instances where combined_df['column'] is equal to "Unrated" to "Not Rated"

combined_df = combined_df.replace({"Unrated" : "Not Rated"})
combined_df['rating'].value_counts()
# Out:
# rating
# R            2597
# PG-13        1729
# PG            907
# G             111
# Not Rated      61
# NC-17          12
# X               1
# Name: count, dtype: int64

# %% [markdown]
# Next, let's look at the genres present.

# %%
combined_df['genre'].value_counts()
# Out:
# genre
# Comedy       1496
# Action       1414
# Drama         862
# Crime         399
# Adventure     326
# Biography     311
# Animation     277
# Horror        251
# Fantasy        41
# Mystery        17
# Thriller        7
# Sci-Fi          6
# Romance         5
# Family          4
# Western         2
# Name: count, dtype: int64

# %% [markdown]
# This looks like a fairly typical distribution of some of the most popular genres, so there is no more cleaning that we need to do here!
#
# Let's check out the distribution of release years, release months, runtimes, and our adjusted budgets and revenues.

# %%
# Distribution of release years
sns.histplot(data = combined_df, x = 'year', bins=40)
plt.title('Distribtion of Film\'s Release Years')
# Out:
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, "Distribtion of Film's Release Years")

# %%
# Distribution of release months
monthly_order_df = combined_df.copy()

months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

monthly_order_df['month'] = pd.Categorical(monthly_order_df['month'], categories=months, ordered=True)
monthly_order_df = monthly_order_df.sort_values(by='month')

month_plot = sns.histplot(data = monthly_order_df, x = 'month', color = 'orange')
month_plot.set_xticklabels(month_plot.get_xticklabels(), rotation=45)
plt.title('Distribution of Film\'s Release Month')
# Out:
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\kietc\AppData\Local\Temp\ipykernel_16484\3944990682.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   month_plot.set_xticklabels(month_plot.get_xticklabels(), rotation=45)
# Text(0.5, 1.0, "Distribution of Film's Release Month")

# %%
# Distribution of runtimes
month_plot = sns.histplot(data = combined_df, x = 'runtime', color = 'yellow')
plt.title('Distribution of Film\'s Runtime')
# Out:
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, "Distribution of Film's Runtime")

# %% [markdown]
# The distribution seems to be centered in the 100-120 minute range, which is to be expected for feature films.

# %%
# Distribution of adjusted budgets
month_plot = sns.histplot(data = combined_df, x = 'adjusted_budget', color = 'red')
plt.title('Distribution of Film\'s Adjusted Budget')
# Out:
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, "Distribution of Film's Adjusted Budget")

# %%
# Distribution of adjusted revenues
month_plot = sns.histplot(data = combined_df, x = 'adjusted_revenue', color = 'green')
plt.title('Distribution of Film\'s Adjusted Revenue')
# Out:
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, "Distribution of Film's Adjusted Revenue")

# %% [markdown]
# The revenus are highly right-skewed. Let's investigate what those high revenue outliers are to determine if they should remain in our data or not.

# %%
combined_df.loc[combined_df['adjusted_revenue'].idxmax()]
# Out:
# name                     Titanic
# rating                     PG-13
# genre                      Drama
# year                        1997
# month                   December
# score                       7.80
# runtime                   194.00
# adjusted_budget     322499506.83
# adjusted_revenue   3550150784.23
# Name: 1795, dtype: object

# %% [markdown]
# This outlier is Titanic, which tracks, as Titanic is historically the highest grossing film of all time! As this is in fact a valid observation, we'll keep it in our dataframe.
#
# Having looked at the rough distributions of all of our key variables, we can see that the distributions are relatively intuitive and look about how we would expect them to, suggesting that our data is cleaned and ready to be explored deeper in Exploratory Data Analysis.

# %% [markdown]
# # Results
# ## Exploratory Data Analysis

# %% [markdown]
# Now that our data is cleaned and usable, we will begin plotting relationships between our movie characteristic information (genre, rating, runtime, budget, revenue, release month) and the IMDB user ratings to see what sorts of trends emerge.
#
# First, we'll look at genre versus IMDB user score.

# %% [markdown]
# ### EDA: Exploring Relationships Between Movie Characteristics and IMDB User Score
#
# Now that our data is cleaned and usable, we will begin plotting relationships between our movie characteristic information (genre, rating, runtime, budget, revenue, release month) and the IMDB user ratings to see what sorts of trends emerge.
#
# First, we'll look at genre versus IMDB user ratings:

# %%
## Bar plot of genres vs IMDB user ratings
sns.boxplot(data=combined_df, y='genre', x='score')
plt.title('Box Plot of Genres vs. IMDB User Score')
# Out:
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Box Plot of Genres vs. IMDB User Score')

# %% [markdown]
# Some of the genres show very little variance in the data - this is because many of these genres only have one or two films in the dataset. In the dataset, films are preferably sorted into more broad genres rather than specific ones, so something like "Star Wars" counts as an Action film rather than sci-fi. These films are still represented, only our analysis will be limited to looking at broader types of films rather than specific niche genres.
#
# Below, we visualize genre versus user score again, this time only considering genres with more than 251 films (as this is where our dataset shows a sharp drop off to the much smaller genres). We also tried randomly sampling from the much larger genres (like dramas) to see if that would result in a more readable relationship.

# %%
grouped_df = combined_df.groupby('genre')

films = []
for genre, group in grouped_df:
    if len(group) >= 251:
        films.append(group.sample(251))

sampled_df = pd.concat(films)

sns.boxplot(data=sampled_df, y='genre', x='score')
plt.title('Box Plot of Genres vs. IMDB User Score - Sampled')
# Out:
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Box Plot of Genres vs. IMDB User Score - Sampled')

# %% [markdown]
# This graph appears much more readable, but as our sampling was random, the shapes of the genres we kept didn't change much, as expected. We can see that biography films appear to have the highest IMDB user ratings on average, with Drama and Animation close behind. The preference for biographies is not incredbily surprising, given the critical success of biopics like Lincoln, or Bohemian Rhapsody, or in recent years, Oppenheimer and Napoleon.
#
# Next, we consider the relationships between a film's MPA rating versus its IMDB user score.

# %%
sns.boxplot(data=combined_df, y='rating', x='score')
plt.title('Box Plot of MPA Rating vs. IMDB User Score')
# Out:
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Box Plot of MPA Rating vs. IMDB User Score')

# %% [markdown]
# It should not be surprising to see so many outliers and a wide interquartile range on these ratings. For any MPA rating, there are films that have performed across the gamut of IMDB user scores. Surpsingly, NC-17 and X rating appear to be much higher rated, but it is worth rememebring that these ratings are extremely rare and as such are underrepresented in the dataset. We can largely disregard these ratings from our analysis due to a lack of data.
#
# Of the more popular ratings, we can see that all genres appear to perform similarly, with G-rated and R-rated films performing slightly better. This makes sense, as R-rated films often contain more serious and "adult" subject matter, making for more "mature" films that perform well with critics. G-rated films are often subject to nostalgia bias in IMDB scores, as exhibited by the very high scores for pixar's animated films, which are mostly rated G.
#
# Next, we look at release month vs IMDB user score.

# %%
sns.boxplot(data=combined_df, y='month', x='score')
plt.title('Box Plot of Release Month vs. IMDB User Ratings')
# Out:
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Box Plot of Release Month vs. IMDB User Ratings')

# %% [markdown]
# Again, the distribution appears to be relatively even, with the differences between months being relatively small. There does appear to be a preference for films released in November, December, and January. This goes against our prediction that summer films would perform better, but when considering that most films competing in the Oscars release toward the end of the year or in the beginning of the following year, a skew in audience scores during these months does seem reasonable.

# %% [markdown]
# Next, we compare our continuous variables, starting with the correlation between runtime and user ratings.

# %%
# Scatterplot comparing runtime to user rating
sns.scatterplot(data=combined_df, x='runtime', y='score', alpha=.5, linewidth = 0)
plt.title('Movie Runtime vs. IMDB User Ratings')
# Out:
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Movie Runtime vs. IMDB User Ratings')

# %% [markdown]
# Most of the data is clustered around the 100-120 minute range, which is to be expected for feature films. However, while there are films with all types of scores for the more typical runtimes, as we move out to longer films, there does seem to be a positive correlation between runtime and user score.
#
# Next, let's look at budget and IMDB rating.

# %%
# Scatterplot comparing adjusted budget to user rating
sns.scatterplot(data=combined_df, x='adjusted_budget', y='score', alpha=.5, linewidth = 0)
plt.title('Budget vs. IMDB User Ratings')
# Out:
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Budget vs. IMDB User Ratings')

# %% [markdown]
# It's hard to tell a clear relationship from this, but there may be a slight positive relationship between budget and score. But again, the wide variability shows that there are films of all scores at each budget point, with it slightly narrowing toward the higher scores as the budget gets much higer.
#
# Next, we consider the relationships between these features and a film's revenue.

# %% [markdown]
# ### EDA: Relationships between Movie Features and Adjusted Revenue

# %% [markdown]
# First, we consider genre versus adjusted revenue.

# %%
sns.boxplot(data=combined_df, y='genre', x='adjusted_revenue')
plt.title('Box Plot of Genres vs. Adjusted Revenue')
# Out:
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Box Plot of Genres vs. Adjusted Revenue')

# %% [markdown]
# We can see that most genres have their average centered around the lower end of the revenue scale, with some far outliers in the action and drama categories (representing Avatar and Titanic).
#
# Interestingly, family films have a much higher average revenue. This may be explained by the fact that parents often take their children to family films, meaning more tickets will be sold and thus they may experience higher revenues.

# %% [markdown]
# We then want to see the relationship between revenue and MPAA rating:

# %%
sns.boxplot(data=combined_df, y='rating', x='adjusted_revenue')
plt.title('Box Plot of Rating vs. Adjusted Revenue')
# Out:
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Box Plot of Rating vs. Adjusted Revenue')

# %% [markdown]
# We can see that G-rated films have a higher average revenue than the other ratings. This is consistent with the results of the genre distribution above, as most family films are rated G. This suggests that a film being marketed toward a family audience may be a significant predictor of its financial success.

# %% [markdown]
# Now, let's look at the relationship between revenue and month

# %%
monthly_order_df = combined_df.copy()

months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

monthly_order_df['month'] = pd.Categorical(monthly_order_df['month'], categories=months, ordered=True)
monthly_order_df = monthly_order_df.sort_values(by='month')

sns.boxplot(data=monthly_order_df, y='month', x='adjusted_revenue')
plt.title('Box Plot of Release Month vs. Adjusted_revenue')
# Out:
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# Text(0.5, 1.0, 'Box Plot of Release Month vs. Adjusted_revenue')

# %% [markdown]
# The means are all relatively similar, but we again see a higher IQR for films released during the summer months. Again, continuing on the theme of family films being financially successful, it makes sense that more of these films would be released during the summer, when children are on summer vacation from school.

# %% [markdown]
# Next, we compare the continuous variables with revenue, starting with runtime.

# %%
# Scatterplot comparing runtime to user rating
sns.scatterplot(data=combined_df, x='runtime', y='adjusted_revenue', alpha=.5, linewidth = 0)
plt.title('Runtime vs. Revenue')
# Out:
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Runtime vs. Revenue')

# %% [markdown]
# There doesn't appear to be any initially visible correlations, though due to the presence of outliers like Titanic, most of the revenues are clustered around zero. We apply a log transform to revenue to see if it yields any new insights:

# %%
combined_df['revenue_log10'] = np.log10(combined_df['adjusted_revenue'] + 0.1)
#combined_df['runtime_log10'] = np.log10(combined_df['runtime'] + 0.1)
sns.scatterplot(data=combined_df, x='runtime', y='revenue_log10', alpha=.5, linewidth = 0)
plt.title('Runtime vs. Revenue (log adjusted)')
# Out:
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Runtime vs. Revenue (log adjusted)')

# %% [markdown]
# Interestingly, the distribution now resembles our earlier distribution of runtime vs IMDB user rating, implying that the relationships may potentially be similar, with a positive correlation between runtime and revenue.
#
# Next, we examine the distribution of budget vs revenue. Note that for all future distributions and models of continuous variables that involve revenue, we will use the log-adjusted value to better see the relationships.

# %%
sns.scatterplot(data=combined_df, x='adjusted_budget', y='revenue_log10', alpha=.5, linewidth = 0)
plt.title('Budget vs. Revenue (log adjusted)')
# Out:
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Budget vs. Revenue (log adjusted)')

# %% [markdown]
# In this distribution, we see a potentially a positive relationship between the budget of a film, and its revenue.

# %% [markdown]
# ### EDA: Relationships between IMDB Rating and Adjusted Revenue
#
# Finally, we compare film revenue and IMDB user rating to see if any correlations exist.

# %%
sns.scatterplot(data=combined_df, x='revenue_log10', y='score')
plt.title('Revenue (log transformed) vs IMDB User Ratings')
# Out:
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Revenue (log transformed) vs IMDB User Ratings')

# %% [markdown]
# While it appears to be very limited, as there is an extremely large amount of variability in the distribution, there may be a slight positive correlation between a film's revenue and its IMDB user score.

# %% [markdown]
# ## Modeling
#
# We primarily used OLS linear regression models to see if there are any statistically significant correlations between our variables of interest, as many of our distributions showed roughly linear relationships, and due to the convenience of the model for the large amount of comparisons we are making.

# %% [markdown]
# ### Genre Models
#
# First, we will run models that predict score and revenue using genre. We first run a linear model to show the effect of a film being in a specific genre on its IMDB user score.

# %%
outcome, predictors = patsy.dmatrices('score ~ genre', data=combined_df)
mod = sm.OLS(outcome, predictors)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  score   R-squared:                       0.097
# Model:                            OLS   Adj. R-squared:                  0.095
# Method:                 Least Squares   F-statistic:                     41.48
# Date:                Mon, 18 Mar 2024   Prob (F-statistic):          7.59e-109
# Time:                        19:34:33   Log-Likelihood:                -7200.6
# No. Observations:                5418   AIC:                         1.443e+04
# Df Residuals:                    5403   BIC:                         1.453e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              6.2475      0.024    256.676      0.000       6.200       6.295
# ...

# %% [markdown]
# In keeping with the earlier visualization, this model shows that being a biography will increase a film's IMDB score by an average of .84, and this is a statistically significant effect due to its small p-value. We also see comedy, fantasy, and horror as predictors of a lower score, but these findings are all statistically insignificant.
#
# We run the model again on the sampled genre data, finding similar results.

# %%
outcome, predictors = patsy.dmatrices('score ~ genre', data=sampled_df)
mod = sm.OLS(outcome, predictors)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  score   R-squared:                       0.145
# Model:                            OLS   Adj. R-squared:                  0.142
# Method:                 Least Squares   F-statistic:                     48.46
# Date:                Mon, 18 Mar 2024   Prob (F-statistic):           7.08e-64
# Time:                        19:34:33   Log-Likelihood:                -2584.4
# No. Observations:                2008   AIC:                             5185.
# Df Residuals:                    2000   BIC:                             5230.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              6.2944      0.055    113.553      0.000       6.186       6.403
# ...

# %% [markdown]
# Next, we run an OLS model predicting revenue using genre.

# %%
outcome, predictors = patsy.dmatrices('adjusted_revenue ~ genre', data=combined_df)
mod = sm.OLS(outcome, predictors)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       adjusted_revenue   R-squared:                       0.116
# Model:                            OLS   Adj. R-squared:                  0.114
# Method:                 Least Squares   F-statistic:                     50.73
# Date:                Mon, 18 Mar 2024   Prob (F-statistic):          1.69e-133
# Time:                        19:34:33   Log-Likelihood:            -1.1171e+05
# No. Observations:                5418   AIC:                         2.235e+05
# Df Residuals:                    5403   BIC:                         2.236e+05
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           2.179e+08    5.8e+06     37.544      0.000    2.07e+08    2.29e+08
# ...

# %% [markdown]
# Again in keeping with our earlier visualizations, it seems that animation and family films are statistically significant predictors of a film having a higher adjusted revenue. Running this regression on our sampled data reveals similar results:

# %%
outcome, predictors = patsy.dmatrices('adjusted_revenue ~ genre', data=sampled_df)
mod = sm.OLS(outcome, predictors)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       adjusted_revenue   R-squared:                       0.170
# Model:                            OLS   Adj. R-squared:                  0.167
# Method:                 Least Squares   F-statistic:                     58.61
# Date:                Mon, 18 Mar 2024   Prob (F-statistic):           1.07e-76
# Time:                        19:34:34   Log-Likelihood:                -41231.
# No. Observations:                2008   AIC:                         8.248e+04
# Df Residuals:                    2000   BIC:                         8.252e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           2.141e+08   1.27e+07     16.916      0.000    1.89e+08    2.39e+08
# ...

# %% [markdown]
# These models confirm what our initial data visualizations revealed: There are statistically significant findings that seem to suggest that biography films on average have higher IMDB user scores, while animation and family films have higher revenues on average.
#
# Next, we consider regression models using release month as a predictor:

# %% [markdown]
# ### Release Month Models
#
# First, we try and fit a model predicting IMDB user score using release month.

# %%
outcome, predictors = patsy.dmatrices('score ~ month', data=combined_df)
mod = sm.OLS(outcome, predictors)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  score   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     6.584
# Date:                Mon, 18 Mar 2024   Prob (F-statistic):           5.09e-11
# Time:                        19:34:34   Log-Likelihood:                -7434.8
# No. Observations:                5413   AIC:                         1.489e+04
# Df Residuals:                    5401   BIC:                         1.497e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              6.2517      0.047    134.244      0.000       6.160       6.343
# ...

# %% [markdown]
# The strongest relationships are shown in November, December, and January, which all have strong positive coefficients and are all statistically significant. This supports our earlier thinking that perhaps films released during awards season will correspond to higher IMDB user scores.
#
# Next we predict revenue using release month.

# %%
outcome, predictors = patsy.dmatrices('adjusted_revenue ~ month', data=combined_df)
mod = sm.OLS(outcome, predictors)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       adjusted_revenue   R-squared:                       0.071
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     37.40
# Date:                Mon, 18 Mar 2024   Prob (F-statistic):           2.84e-78
# Time:                        19:34:34   Log-Likelihood:            -1.1175e+05
# No. Observations:                5413   AIC:                         2.235e+05
# Df Residuals:                    5401   BIC:                         2.236e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           9.094e+07   1.09e+07      8.347      0.000    6.96e+07    1.12e+08
# ...

# %% [markdown]
# Again, we see a statistically significant increase in a film's revenue when they are released May, June, or July, further lending support to the working hypothesis that children-oriented films bring in higher revenues. It follows that these films would be released during the summer, when most kids are on break from school.

# %% [markdown]
# ### Rating Models
#
# We now run the same models, using MPAA ratings as our predictor.

# %%
outcome, predictors = patsy.dmatrices('score ~ rating', data=combined_df)
mod = sm.OLS(outcome, predictors)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  score   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     17.03
# Date:                Mon, 18 Mar 2024   Prob (F-statistic):           1.36e-19
# Time:                        19:34:34   Log-Likelihood:                -7426.5
# No. Observations:                5418   AIC:                         1.487e+04
# Df Residuals:                    5411   BIC:                         1.491e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               6.5631      0.091     72.516      0.000       6.386       6.740
# ...

# %% [markdown]
# Most of the relationships between MPAA rating and IMDB user score are not statistically significant, and those that are have only a minor effect. PG and PG-13 ratings have small negative coefficients, and Not Rated has a somewhat small positive coefficient. As most of the effects are not significant, and those that are are very small, it is likely that MPAA ratings are not a significant predictor of IMDB score.

# %%
outcome, predictors = patsy.dmatrices('adjusted_revenue ~ rating', data=combined_df)
mod = sm.OLS(outcome, predictors)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       adjusted_revenue   R-squared:                       0.068
# Model:                            OLS   Adj. R-squared:                  0.067
# Method:                 Least Squares   F-statistic:                     65.73
# Date:                Mon, 18 Mar 2024   Prob (F-statistic):           3.72e-79
# Time:                        19:34:34   Log-Likelihood:            -1.1186e+05
# No. Observations:                5418   AIC:                         2.237e+05
# Df Residuals:                    5411   BIC:                         2.238e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept            2.676e+08   2.13e+07     12.588      0.000    2.26e+08    3.09e+08
# ...

# %% [markdown]
# Interestingly, all of the relationships between MPAA rating and revenue are statistically significant except for X-rating (as there was only 1 x-rated movie in the sample). All of the coefficients are negative, with PG and PG-13 bringing down the revenue less than other ratings.

# %% [markdown]
# ### Runtime Models

# %% [markdown]
# Moving into the continuous variables, we decided to plot the regression model as a best-fit line to more clearly see the relationships that exist. We begin with the runtime models.

# %%
sns.scatterplot(x='runtime', y='score', data=combined_df)
sns.regplot(x='runtime', y='score', data=combined_df, ci=None, line_kws={'color': 'red'})

slope, intercept, r_value, p_value, std_err = linregress(combined_df['runtime'], combined_df['score'])
print(slope)
print(p_value)
plt.title('Runtime vs. Score with Regression Line')
plt.show()
# Out:
# 0.022013410981403195
# 4.659991272974831e-224
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# Here we do see a positive relationship between runtime and IMDB score, though we can see from the large amount of variance in the distribution around the line that this relationship may not be incredibly significant.
#
# We then run a regression model on our log-adjusted revenue using runtime as a predictor.

# %%
sns.scatterplot(x='runtime', y='revenue_log10', data=combined_df)
sns.regplot(x='runtime', y='revenue_log10', data=combined_df, ci=None, line_kws={'color': 'red'})

slope, intercept, r_value, p_value, std_err = linregress(combined_df['runtime'], combined_df['revenue_log10'])
print(slope)
plt.title('Runtime vs. Revenue (log transformed) with Regression Line')
plt.show()
# Out:
# 0.010889422491575807
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# While there is a correlation, the very small slope indicates that there is not a very strong relationship between runtime and a film's revenue.

# %% [markdown]
# ### Budget Models

# %% [markdown]
# We similarly run regression models on using budget as our predictor, plotting the best-fit line from the regression model onto the distribution.

# %%
sns.scatterplot(x='adjusted_budget', y='score', data=combined_df)
sns.regplot(x='adjusted_budget', y='score', data=combined_df, ci=None, line_kws={'color': 'red'})

slope, intercept, r_value, p_value, std_err = linregress(combined_df['adjusted_budget'], combined_df['score'])
print(slope)
print(p_value)
plt.title('Adjusted Budget vs. Score with Regression Line')
plt.show()
# Out:
# 1.155901475626581e-09
# 9.56497043527977e-06
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# Here we see essentially no relationship between a film's budget and its IMDB score. As our best-fit line is almost horizontal, we can see that there is a negligble relationship between the two variables. This indicates that budget is not a good preditor of a film's favor with audiences, and that films of any budget can receive a variety of user scores.
#
# Next, we attempt to fit a line for budget to our log-adjusted revenue distribution.

# %%
sns.scatterplot(x='adjusted_budget', y='revenue_log10', data=combined_df)
sns.regplot(x='adjusted_budget', y='revenue_log10', data=combined_df, ci=None, line_kws={'color': 'red'})

slope, intercept, r_value, p_value, std_err = linregress(combined_df['adjusted_budget'], combined_df['revenue_log10'])
print(slope)
plt.title('Adjusted Budget vs. Revenue (log transformed) with Regression Line')
plt.show()
# Out:
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# 9.177681520036095e-09

# %% [markdown]
# Here we can see a positive relationship between a film's budget, and its revenue. This perhaps suggests that films with higher budgets and production values perform better at the box office. This is perhaps because films with higher budgets are often very commercially popular blockbuster films like superhero movies.

# %% [markdown]
# ### Revenue vs User Score Model

# %% [markdown]
# Finally, we run a model seeing if a film's revenue can be used as a predictor for its IMDB user score.

# %%
sns.scatterplot(data=combined_df, x='adjusted_revenue', y='score')
sns.regplot(x='adjusted_revenue', y='score', data=combined_df, ci=None, line_kws={'color': 'red'})
plt.title('Revenue (log transformed) vs IMDB User Ratings')

slope, intercept, r_value, p_value, std_err = linregress(combined_df['score'], combined_df['adjusted_revenue'])
print(slope)
# Out:
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\kietc\anaconda3\envs\cogs\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# 58807290.83514742

# %% [markdown]
# The above model suggests that there is some relationship to be seen between revenue and score, though the large variability toward the lower revenues suggest that a film's revenue is perhaps only predictive of its score as the revenue becomes very large.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# Throughout our research project, we aim to keep ethical practice and user privacy as top priorities in our process. All data we plan to use will be publicly available. A film’s revenue and information about its characteristics are all publicly available and impersonal information, and the IMDB average rating for a film is a mean taken from several anonymous individual reviewers, meaning our variables of interest are all ethically sourced. Our datasets will likely mostly be taken from Kaggle, which hosts publicly available data, and we plan to take full responsibility for the ethical implications of our results.
#
# While movies are a fairly casual and broad topic, we were careful in selecting our variables to consider any analysis that may be sensitive or allow room for misleading results or interpretations. While we are accessing user’s ratings of a film on IMDB, we have no access to user’s personal information, and are instead pulling an average rating from the scores of countless users, meaning the privacy of IMDB users is protected. We are committed to analyzing our data and interpreting our results in an objective and unbiased manner, and will strive to avoid misrepresenting our results or engaging in any faulty analytical practices (p-hacking, etc.). By choosing our data carefully and dedicating ourselves to fair research practices, we hope to maintain ethics and privacy in our project.

# %% [markdown]
# # Discussion and Conclusion
#
# In comparing our findings to our initial hypothesis, we see some striking differences. For IMDB scores, we hypothesized that budget and runtime would both be positively correlated with score, and that "R" ratings, drama genre films, and summer release months would also be predictors of a higher IMDB score. While we do see a positive correlation between a film's runtime and its user score, there is only a negligably small relationship between budget and score. Further, we found that aside from some small coefficients related to PG and PG-13, the MPA rating has no statistically significant effect on a film's IMDB score. Rather than drama films released during the summer, we also saw that biographies and films released during the winter months were statistically significant predictors of a higher IMDB score. We reasoned that these results can be explained by the fact that films aiming to win awards like Oscars often release during the end of the year, and that historically, many of these awards-focused, critically successful films have been biopics. More recent examples of films following this trend would be films like "Maestro," which was a biography released in December 2023, that went on to gain critical success and an extensive awards season run. In future analyses, it would be interesting to see if there is a relationship between how many major awards a film wins, and its IMDB score.
#
# We predicted that the same characteristics would also correlate with a higher revenue for a film. Unlike the IMDB score models, we did see a positive relationship between a film's budget and its revenue, with less variance in the distribution as the budget increased. This suggests that bigger budget films are more lucrative. As with IMDB score, we saw little statistically significant results between MPA rating and revenue. We saw a slight positive relationship between runtime and revenue, though there is a wide amount of variability in this distribution. For genre and release month, our models show that family or animation films, as well as films released during May, June, or July all are more likely to have higher revenues. Based on these results, we now predict that perhaps the films that are most lucrative are ones aimed towards children. Parents looking to make their kids happy will pay to see family-oriented films, and purchasing a family's worth of tickets generates more revenue. This would explain why the most lucrative genres are animation and family (genres traditionally geared towards children), and why the most lucrative release months fall in the summer, when children are on vacation from school.
#
# Our analysis is far from perfect, however. First, our data is incredibly limited. As we saw during our EDA, the way our dataset categorizes genre eliminated a lot of potential nuance in our results. This likely skewed our results away from more niche genres like sci-fi or westerns, and towards more vague ones like "family" and "drama." Additionally, our dataset only included films released from 1980-2020. It would have been interested to see if the trends we saw in our models held across a wider timeframe. With over one hundred years of film history, selecting only 40 years limits the generalizability of our results. In future analyses, we would like to pick a more robust dataset that includes a wider variety of genres, larger stretches of time, and international films that don't only come from Hollywood.
#
# As streaming services and the pandemic have greatly reshaped the way the industry distributes and markets films, it becomes increasingly prudent to consider the types of films most likely to perform well with audiences, in order to get moviegoers back into theaters.
#
# # Team Contributions
#
# - Jack: Background research, data wrangling, regression modeling and analysis
# - Karisma: Background research, researched inflation datasets and approaches, visualizations
# - Chengyuan: Background research, data wrangling, cleaning visualizations
# - Anthony: Background research, abstract, final report writing
# - James: Data wrangling, EDA visualizations, final report writing
